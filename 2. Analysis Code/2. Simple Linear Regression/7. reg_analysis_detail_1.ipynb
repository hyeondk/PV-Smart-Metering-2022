# %% [markdown]
# ### **Code** : **PV Smart-Metering Regression Analysis_Detail_1**
# - Writer : Donghyeon Kim
# - Date : 2022.08.03
# - Data : 태양광 사용가구 '김OO' 2021/4
# - Reason : 1,440개의 행(60분 X 24시간)을 가장 많이 지니고 있는 가구이므로 선정함.

# %% [markdown]
# <hr>

# %% [markdown]
# ### **0. Running the library and setting up the foundation**

# %%
# 1. 라이브러리 실행
from pathlib import Path
import os
import pandas as pd
import numpy as np 
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# 2. 파일의 상위-상위 경로 설정
os_root = Path(os.path.join(os.getcwd(), '7. reg_analysis_detail_1.ipynb'))
root = os_root.parent.parent

# %% [markdown]
# #### **User Data**

# %%
# 3. 사용자 데이터 호출
# User data 폴더
user_folder_root = os.path.join(root, 'data_revised_hour')

# 사용자 이름
folder_root = os.path.join(root, 'data')
user_name = os.listdir(folder_root)

# FIXME
user = '김OO'

# 사용자 이름 index
idx = user_name.index(user)

# xlsx 파일 이름
xlsx_name = user_folder_root + '\\' + f'{user_name[idx]}_dataset_revised_hour.xlsx'

# 데이터 호출
df_user = pd.read_excel(xlsx_name)

# %%
df_user.head(24)
# Out:
#                   date  year  month  day  hour  그리드 소비(kWh)  수출 된 에너지(kWh)  \
# 0  2021-03-01 00:59:00  2021      3    1     0     0.200001       0.000000
# 1  2021-03-01 01:59:00  2021      3    1     1     0.250000       0.000000
# 2  2021-03-01 02:59:00  2021      3    1     2     0.210003       0.000000
# 3  2021-03-01 03:59:00  2021      3    1     3     0.180000       0.000000
# 4  2021-03-01 04:59:00  2021      3    1     4     0.190002       0.000000
# 5  2021-03-01 05:59:00  2021      3    1     5     0.200001       0.000000
# 6  2021-03-01 06:59:00  2021      3    1     6     0.299999       0.000000
# 7  2021-03-01 07:59:00  2021      3    1     7     0.270000       0.000000
# 8  2021-03-01 08:59:00  2021      3    1     8     0.399998       0.000000
# 9  2021-03-01 09:59:00  2021      3    1     9     0.219997       0.000000
# 10 2021-03-01 10:59:00  2021      3    1    10     0.139999       0.000000
# 11 2021-03-01 11:59:00  2021      3    1    11     0.110001       0.000000
# 12 2021-03-01 12:59:00  2021      3    1    12     0.110001       0.019997
# 13 2021-03-01 13:59:00  2021      3    1    13     0.080002       0.010002
# 14 2021-03-01 14:59:00  2021      3    1    14     0.149998       0.010002
# 15 2021-03-01 15:59:00  2021      3    1    15     0.139999       0.000000
# 16 2021-03-01 16:59:00  2021      3    1    16     0.209999       0.000000
# 17 2021-03-01 17:59:00  2021      3    1    17     0.269997       0.000000
# 18 2021-03-01 18:59:00  2021      3    1    18     0.470001       0.000000
# 19 2021-03-01 19:59:00  2021      3    1    19     0.349998       0.000000
# 20 2021-03-01 20:59:00  2021      3    1    20     0.279999       0.000000
# 21 2021-03-01 21:59:00  2021      3    1    21     0.280003       0.000000
# 22 2021-03-01 22:59:00  2021      3    1    22     0.309998       0.000000
# 23 2021-03-01 23:59:00  2021      3    1    23     0.220001       0.000000
#
#     에너지 수율(kWh)
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# 5      0.000000
# 6      0.000000
# 7      0.000000
# 8      0.000000
# 9      0.050003
# 10     0.099991
# 11     0.150009
# 12     0.139999
# 13     0.210007
# 14     0.110001
# 15     0.069992
# 16     0.029999
# 17     0.000000
# 18     0.000000
# 19     0.000000
# 20     0.000000
# 21     0.000000
# 22     0.000000
# 23     0.000000

# %%
# Merge를 위한 column filtering
df_user_filter = df_user.drop(['date'], axis = 1)

# %%
df_user_filter.head(24)
# Out:
#     year  month  day  hour  그리드 소비(kWh)  수출 된 에너지(kWh)  에너지 수율(kWh)
# 0   2021      3    1     0     0.200001       0.000000     0.000000
# 1   2021      3    1     1     0.250000       0.000000     0.000000
# 2   2021      3    1     2     0.210003       0.000000     0.000000
# 3   2021      3    1     3     0.180000       0.000000     0.000000
# 4   2021      3    1     4     0.190002       0.000000     0.000000
# 5   2021      3    1     5     0.200001       0.000000     0.000000
# 6   2021      3    1     6     0.299999       0.000000     0.000000
# 7   2021      3    1     7     0.270000       0.000000     0.000000
# 8   2021      3    1     8     0.399998       0.000000     0.000000
# 9   2021      3    1     9     0.219997       0.000000     0.050003
# 10  2021      3    1    10     0.139999       0.000000     0.099991
# 11  2021      3    1    11     0.110001       0.000000     0.150009
# 12  2021      3    1    12     0.110001       0.019997     0.139999
# 13  2021      3    1    13     0.080002       0.010002     0.210007
# 14  2021      3    1    14     0.149998       0.010002     0.110001
# 15  2021      3    1    15     0.139999       0.000000     0.069992
# 16  2021      3    1    16     0.209999       0.000000     0.029999
# 17  2021      3    1    17     0.269997       0.000000     0.000000
# 18  2021      3    1    18     0.470001       0.000000     0.000000
# 19  2021      3    1    19     0.349998       0.000000     0.000000
# 20  2021      3    1    20     0.279999       0.000000     0.000000
# 21  2021      3    1    21     0.280003       0.000000     0.000000
# 22  2021      3    1    22     0.309998       0.000000     0.000000
# 23  2021      3    1    23     0.220001       0.000000     0.000000

# %% [markdown]
# <hr>

# %% [markdown]
# ### **1. Data Pre-processing for Regression Analysis**

# %% [markdown]
# #### **<Data 1 : Weather Data>**

# %% [markdown]
# #### **Data Pre-processing**

# %%
# weather data 폴더
weather_folder_root = os.path.join(root, 'data_weather')

# csv 파일 이름
csv_name = weather_folder_root + '\\' + 'keei_ldaps.csv'

# 데이터 호출
df_weather = pd.read_csv(csv_name, encoding='cp949')

# %%
# 데이터 정제
df_weather['dt'] = pd.to_datetime(df_weather['dt'], format='%Y/%m/%d %H:%M:%S')
df_weather['year'] = df_weather['dt'].dt.year
df_weather['month'] = df_weather['dt'].dt.month
df_weather['day'] = df_weather['dt'].dt.day
df_weather['hour'] = df_weather['dt'].dt.hour

# %%
# 태양광 사용 가구 : '김OO'
df_weather_use = df_weather[df_weather.owner == '김OO']

# %%
# Data Merge
df_weather_use = pd.merge(df_weather_use, df_user_filter, how='left', on=['year', 'month', 'day', 'hour'])

# %%
# Column 이름 변경
df_weather_use.rename(columns={'그리드 소비(kWh)': 'grid_kWh', '수출 된 에너지(kWh)': 'export_kWh', '에너지 수율(kWh)': 'yield_kWh'}, inplace=True)

# %%
df_weather_use.drop(['owner', 'id_hh', 'id_hs'], axis=1).tail(10)
# Out:
#                              dt  temperature   uws_10m   vws_10m         ghi  \
# 13840 2022-04-30 15:00:00+09:00   289.807922  1.103254  2.136642  243.770538
# 13841 2022-04-30 16:00:00+09:00   290.679688  3.716064  0.633899  284.969421
# 13842 2022-04-30 17:00:00+09:00   289.007690  3.104170  1.623195  331.664551
# 13843 2022-04-30 18:00:00+09:00   287.392883  2.541556  1.322166  187.572693
# 13844 2022-04-30 19:00:00+09:00   285.536194  1.803355  2.358898   50.007076
# 13845 2022-04-30 20:00:00+09:00   284.207703  1.945932  1.498594    1.366211
# 13846 2022-04-30 21:00:00+09:00   282.821838  0.995493  1.326086    0.000000
# 13847 2022-04-30 22:00:00+09:00   281.902527  0.671311  1.957892    0.000000
# 13848 2022-04-30 23:00:00+09:00   281.104187  0.343318  2.047524    0.000000
# 13849 2022-05-01 00:00:00+09:00   280.501892  0.750398  1.590288    0.000000
#
#        precipitation  relative_humidity_1p5m  specific_humidity_1p5m place  \
# 13840            0.0               75.599068                0.006213    서울
# 13841            0.0               70.625931                0.006306    서울
# 13842            0.0               78.621765                0.005859    서울
# 13843            0.0               80.893768                0.005859    서울
# 13844            0.0               84.606339                0.005744    서울
# 13845            0.0               87.228836                0.005584    서울
# 13846            0.0               85.965973                0.005168    서울
# 13847            0.0               83.123375                0.005127    서울
# 13848            0.0               80.482849                0.004883    서울
# 13849            0.0               77.866310                0.004686    서울
#
#        year  month  day  hour  grid_kWh  export_kWh  yield_kWh
# 13840  2022      4   30    15  0.000000    0.370117   0.680176
# 13841  2022      4   30    16  0.000000    0.319824   0.470215
# 13842  2022      4   30    17  0.020020    0.130127   0.370117
# 13843  2022      4   30    18  0.100098    0.070068   0.180176
# 13844  2022      4   30    19  0.709961    0.000000   0.000000
# 13845  2022      4   30    20  0.290039    0.000000   0.000000
# 13846  2022      4   30    21  0.320068    0.000000   0.000000
# 13847  2022      4   30    22  0.260010    0.000000   0.000000
# 13848  2022      4   30    23  0.209961    0.000000   0.000000
# 13849  2022      5    1     0       NaN         NaN        NaN

# %%
# 데이터에 해당하는 연도 / 21년도에 해당하는 월 / 22년도에 해당하는 월
# 데이터 기간 : 2021.03 ~ 2022.04
d_year = [2021, 2022]
d_month_21 = range(3, 12+1)
d_month_22 = range(1, 4+1)

# %%
# 2021.03 ~ 2022.04 기간에 해당하는 데이터만 필터링
for y in d_year:
    count = 0
    if y == 2021:
        for ma in d_month_21:
            temp = df_weather_use[(df_weather_use.year == y) & (df_weather_use.month == ma)]
            if count == 0:
                result = temp
                count += 1
            else:
                result = pd.concat([result, temp])
    elif y == 2022:
        for mb in d_month_22:
            temp = df_weather_use[(df_weather_use.year == y) & (df_weather_use.month == mb)]
            result = pd.concat([result, temp])

df_weather_use = result

# %%
# 온도(temperature) 변환
# 기존 형태 : Kelvin(켈빈 온도) -> 변경하고자 하는 형태 : 섭씨 온도
# 섭씨 온도와 켈빈 온도 관계식 : 0(C) + 273.15(K) = 273.15(K)

df_weather_use.temperature = df_weather_use.temperature - 273.15

# %%
df_weather_use.drop(['owner', 'id_hh', 'id_hs'], axis=1).head(24)
# Out:
#                             dt  temperature   uws_10m   vws_10m        ghi  \
# 3625 2021-03-01 00:00:00+09:00    10.322687  0.858208  0.041718   0.000000
# 3626 2021-03-01 01:00:00+09:00    10.029108  0.135828 -1.085083   0.000000
# 3627 2021-03-01 02:00:00+09:00     9.844873  0.362611 -0.180941   0.000000
# 3628 2021-03-01 03:00:00+09:00     9.587915 -0.411156  0.997797   0.000000
# 3629 2021-03-01 04:00:00+09:00     9.564752 -0.462263 -0.222837   0.000000
# 3630 2021-03-01 05:00:00+09:00     9.363092  0.721948 -2.010242   0.000000
# 3631 2021-03-01 06:00:00+09:00     8.639551 -1.163785 -1.346743   0.000000
# 3632 2021-03-01 07:00:00+09:00     8.481317 -0.673493 -1.971651   0.000000
# 3633 2021-03-01 08:00:00+09:00     8.494592 -1.207814 -0.468723   3.883789
# 3634 2021-03-01 09:00:00+09:00     8.613031 -5.542665  1.533955  18.028790
# 3635 2021-03-01 10:00:00+09:00     8.906549 -5.163773  2.200851  31.750060
# 3636 2021-03-01 11:00:00+09:00     9.138910 -4.829136  2.557592  47.240856
# 3637 2021-03-01 12:00:00+09:00     9.414240 -5.172380  3.256266  48.865765
# 3638 2021-03-01 13:00:00+09:00     9.645532 -5.627791  3.719301  39.161011
# 3639 2021-03-01 14:00:00+09:00     9.989221 -4.407599  4.085091  35.391941
# 3640 2021-03-01 15:00:00+09:00    10.326349 -4.401629  3.479259  36.262646
# 3641 2021-03-01 16:00:00+09:00    10.369684 -2.934569  2.791477  13.974899
# 3642 2021-03-01 17:00:00+09:00    10.144373 -0.247665 -1.993122   7.707717
# 3643 2021-03-01 18:00:00+09:00     9.602380 -0.483656 -1.859259   4.003906
# 3644 2021-03-01 19:00:00+09:00     9.099481 -0.472173 -1.156418   0.172852
# 3645 2021-03-01 20:00:00+09:00     8.154779 -0.051892 -2.726320   0.000000
# 3646 2021-03-01 21:00:00+09:00     6.627435 -0.172322 -4.648523   0.000000
# 3647 2021-03-01 22:00:00+09:00     5.526880 -0.111337 -4.442308   0.000000
# 3648 2021-03-01 23:00:00+09:00     4.172998 -0.215252 -4.453913   0.000000
#
#       precipitation  relative_humidity_1p5m  specific_humidity_1p5m place  \
# 3625       0.000000               60.644928                0.004421    서울
# 3626       0.000000               56.432068                0.004188    서울
# 3627       0.000000               62.081512                0.004626    서울
# 3628       0.000000               56.335152                0.004261    서울
# 3629       0.000000               61.451012                0.004599    서울
# 3630       0.000000               64.313083                0.004559    서울
# 3631       2.439514               92.884331                0.005859    서울
# 3632       1.226685               94.962051                0.006039    서울
# 3633       1.170898               93.874001                0.005951    서울
# 3634       0.239624               88.038452                0.005981    서울
# 3635       0.250610               88.133858                0.006157    서울
# 3636       1.424683               89.441917                0.006352    서울
# 3637       2.916443               89.743111                0.006561    서울
# 3638       3.892700               89.500946                0.006771    서울
# 3639       4.988892               91.003967                0.007080    서울
# 3640       3.845337               91.710564                0.007324    서울
# 3641       7.232544               91.111229                0.007388    서울
# 3642       9.810913               96.589668                0.007301    서울
# 3643       5.761963               95.369614                0.006734    서울
# 3644       4.000977               93.264328                0.006267    서울
# 3645       2.614136               91.795578                0.005517    서울
# 3646       2.788086               92.126251                0.004883    서울
# 3647       1.429199               91.985275                0.004425    서울
# 3648       1.401489               96.228485                0.004150    서울
#
#       year  month  day  hour  grid_kWh  export_kWh  yield_kWh
# 3625  2021      3    1     0  0.200001    0.000000   0.000000
# 3626  2021      3    1     1  0.250000    0.000000   0.000000
# 3627  2021      3    1     2  0.210003    0.000000   0.000000
# 3628  2021      3    1     3  0.180000    0.000000   0.000000
# 3629  2021      3    1     4  0.190002    0.000000   0.000000
# 3630  2021      3    1     5  0.200001    0.000000   0.000000
# 3631  2021      3    1     6  0.299999    0.000000   0.000000
# 3632  2021      3    1     7  0.270000    0.000000   0.000000
# 3633  2021      3    1     8  0.399998    0.000000   0.000000
# 3634  2021      3    1     9  0.219997    0.000000   0.050003
# 3635  2021      3    1    10  0.139999    0.000000   0.099991
# 3636  2021      3    1    11  0.110001    0.000000   0.150009
# 3637  2021      3    1    12  0.110001    0.019997   0.139999
# 3638  2021      3    1    13  0.080002    0.010002   0.210007
# 3639  2021      3    1    14  0.149998    0.010002   0.110001
# 3640  2021      3    1    15  0.139999    0.000000   0.069992
# 3641  2021      3    1    16  0.209999    0.000000   0.029999
# 3642  2021      3    1    17  0.269997    0.000000   0.000000
# 3643  2021      3    1    18  0.470001    0.000000   0.000000
# 3644  2021      3    1    19  0.349998    0.000000   0.000000
# 3645  2021      3    1    20  0.279999    0.000000   0.000000
# 3646  2021      3    1    21  0.280003    0.000000   0.000000
# 3647  2021      3    1    22  0.309998    0.000000   0.000000
# 3648  2021      3    1    23  0.220001    0.000000   0.000000

# %% [markdown]
# <hr>

# %% [markdown]
# #### **<Data 2 : Visibility Data>**

# %% [markdown]
# #### **Data Pre-processing**

# %%
# ASOS data 폴더
asos_folder_root = os.path.join(root, 'data_ASOS')

# csv 파일 이름
csv_file_name = ['OBS_ASOS_TIM_1.csv', 'OBS_ASOS_TIM_2.csv']

# 데이터 호출
for i in range(len(csv_file_name)):
    csv_name = asos_folder_root + '\\' + csv_file_name[i]
    if i == 0:
        df_asos = pd.read_csv(csv_name, encoding='cp949')
    else:
        temp = pd.read_csv(csv_name, encoding='cp949')
        df_asos = pd.concat([df_asos, temp])

# %%
df_asos['일시'] = pd.to_datetime(df_asos['일시'], format='%Y/%m/%d %H:%M:%S')
df_asos['year'] = df_asos['일시'].dt.year
df_asos['month'] = df_asos['일시'].dt.month
df_asos['day'] = df_asos['일시'].dt.day
df_asos['hour'] = df_asos['일시'].dt.hour

# %%
df_asos.head(10)
# Out:
#    지점 지점명                  일시  시정(10m)  year  month  day  hour
# 0  90  속초 2021-03-01 00:00:00     2000  2021      3    1     0
# 1  90  속초 2021-03-01 01:00:00     2000  2021      3    1     1
# 2  90  속초 2021-03-01 02:00:00     2000  2021      3    1     2
# 3  90  속초 2021-03-01 03:00:00     1951  2021      3    1     3
# 4  90  속초 2021-03-01 04:00:00     1877  2021      3    1     4
# 5  90  속초 2021-03-01 05:00:00     1630  2021      3    1     5
# 6  90  속초 2021-03-01 06:00:00      713  2021      3    1     6
# 7  90  속초 2021-03-01 07:00:00      794  2021      3    1     7
# 8  90  속초 2021-03-01 08:00:00      716  2021      3    1     8
# 9  90  속초 2021-03-01 09:00:00      906  2021      3    1     9

# %%
# 지점명 체크
df_asos['지점명'].unique()
# Out:
# array(['속초', '북춘천', '철원', '동두천', '파주', '대관령', '춘천', '백령도', '북강릉', '강릉',
#        '동해', '서울', '인천', '원주', '울릉도', '수원', '영월', '충주', '서산', '울진', '청주',
#        '대전', '추풍령', '안동', '상주', '포항', '군산', '대구', '전주', '울산', '창원', '광주',
#        '부산', '통영', '목포', '여수', '흑산도', '완도', '고창', '순천', '홍성', '제주', '고산',
#        '성산', '서귀포', '진주', '강화', '양평', '이천', '인제', '홍천', '태백', '정선군', '제천',
#        '보은', '천안', '보령', '부여', '금산', '세종', '부안', '임실', '정읍', '남원', '장수',
#        '고창군', '영광군', '김해시', '순창군', '북창원', '양산시', '보성군', '강진군', '장흥', '해남',
#        '고흥', '의령군', '함양군', '광양시', '진도군', '봉화', '영주', '문경', '청송군', '영덕',
#        '의성', '구미', '영천', '경주시', '거창', '합천', '밀양', '산청', '거제', '남해'],
#       dtype=object)

# %%
# '김OO' 가구 위치는 '서울'이므로 해당 지역으로 필터링
df_asos_filter = df_asos[df_asos['지점명'] == '서울']

# %%
# Data Merge
df_asos_filter = pd.merge(df_asos_filter, df_user_filter, how='left', on=['year', 'month', 'day', 'hour'])

# %%
# Column 이름 변경
df_asos_filter.rename(columns={'그리드 소비(kWh)': 'grid_kWh', '수출 된 에너지(kWh)': 'export_kWh',
                               '에너지 수율(kWh)': 'yield_kWh', '시정(10m)': 'visibility', '지점명': 'place'}, inplace=True)

# %%
df_asos_filter = df_asos_filter.drop(['지점', '일시'], axis = 1)

# %%
df_asos_filter.head(24)
# Out:
#    place  visibility  year  month  day  hour  grid_kWh  export_kWh  yield_kWh
# 0     서울        2000  2021      3    1     0  0.200001    0.000000   0.000000
# 1     서울        2000  2021      3    1     1  0.250000    0.000000   0.000000
# 2     서울        2000  2021      3    1     2  0.210003    0.000000   0.000000
# 3     서울        2000  2021      3    1     3  0.180000    0.000000   0.000000
# 4     서울         447  2021      3    1     4  0.190002    0.000000   0.000000
# 5     서울        1303  2021      3    1     5  0.200001    0.000000   0.000000
# 6     서울         587  2021      3    1     6  0.299999    0.000000   0.000000
# 7     서울         381  2021      3    1     7  0.270000    0.000000   0.000000
# 8     서울         381  2021      3    1     8  0.399998    0.000000   0.000000
# 9     서울         294  2021      3    1     9  0.219997    0.000000   0.050003
# 10    서울         322  2021      3    1    10  0.139999    0.000000   0.099991
# 11    서울         307  2021      3    1    11  0.110001    0.000000   0.150009
# 12    서울         351  2021      3    1    12  0.110001    0.019997   0.139999
# 13    서울         365  2021      3    1    13  0.080002    0.010002   0.210007
# 14    서울         622  2021      3    1    14  0.149998    0.010002   0.110001
# 15    서울         527  2021      3    1    15  0.139999    0.000000   0.069992
# 16    서울         647  2021      3    1    16  0.209999    0.000000   0.029999
# 17    서울         842  2021      3    1    17  0.269997    0.000000   0.000000
# 18    서울         778  2021      3    1    18  0.470001    0.000000   0.000000
# 19    서울         683  2021      3    1    19  0.349998    0.000000   0.000000
# 20    서울         392  2021      3    1    20  0.279999    0.000000   0.000000
# 21    서울         768  2021      3    1    21  0.280003    0.000000   0.000000
# 22    서울         235  2021      3    1    22  0.309998    0.000000   0.000000
# 23    서울         231  2021      3    1    23  0.220001    0.000000   0.000000

# %% [markdown]
# <hr>

# %% [markdown]
# ### **2. Regression Analysis**

# %% [markdown]
# #### **1) Creating Data & Pre-processing**

# %%
# 회귀분석 진행을 위한 데이터 생성
reg_data = pd.merge(df_weather_use, df_asos_filter, how='left', on=['year', 'month', 'day', 'hour', 'place', 'grid_kWh', 'export_kWh', 'yield_kWh'])

# %%
reg_data = reg_data.drop(['owner', 'id_hh', 'id_hs'], axis = 1)

# %%
reg_data.loc[:, 'ym'] = reg_data.year.astype(str) + '/' + reg_data.month.astype(str)

# %%
reg_data.head(10)
# Out:
#                          dt  temperature   uws_10m   vws_10m        ghi  \
# 0 2021-03-01 00:00:00+09:00    10.322687  0.858208  0.041718   0.000000
# 1 2021-03-01 01:00:00+09:00    10.029108  0.135828 -1.085083   0.000000
# 2 2021-03-01 02:00:00+09:00     9.844873  0.362611 -0.180941   0.000000
# 3 2021-03-01 03:00:00+09:00     9.587915 -0.411156  0.997797   0.000000
# 4 2021-03-01 04:00:00+09:00     9.564752 -0.462263 -0.222837   0.000000
# 5 2021-03-01 05:00:00+09:00     9.363092  0.721948 -2.010242   0.000000
# 6 2021-03-01 06:00:00+09:00     8.639551 -1.163785 -1.346743   0.000000
# 7 2021-03-01 07:00:00+09:00     8.481317 -0.673493 -1.971651   0.000000
# 8 2021-03-01 08:00:00+09:00     8.494592 -1.207814 -0.468723   3.883789
# 9 2021-03-01 09:00:00+09:00     8.613031 -5.542665  1.533955  18.028790
#
#    precipitation  relative_humidity_1p5m  specific_humidity_1p5m place  year  \
# 0       0.000000               60.644928                0.004421    서울  2021
# 1       0.000000               56.432068                0.004188    서울  2021
# 2       0.000000               62.081512                0.004626    서울  2021
# 3       0.000000               56.335152                0.004261    서울  2021
# 4       0.000000               61.451012                0.004599    서울  2021
# 5       0.000000               64.313083                0.004559    서울  2021
# 6       2.439514               92.884331                0.005859    서울  2021
# 7       1.226685               94.962051                0.006039    서울  2021
# 8       1.170898               93.874001                0.005951    서울  2021
# 9       0.239624               88.038452                0.005981    서울  2021
#
#    month  day  hour  grid_kWh  export_kWh  yield_kWh  visibility      ym
# 0      3    1     0  0.200001         0.0   0.000000        2000  2021/3
# 1      3    1     1  0.250000         0.0   0.000000        2000  2021/3
# 2      3    1     2  0.210003         0.0   0.000000        2000  2021/3
# 3      3    1     3  0.180000         0.0   0.000000        2000  2021/3
# 4      3    1     4  0.190002         0.0   0.000000         447  2021/3
# 5      3    1     5  0.200001         0.0   0.000000        1303  2021/3
# 6      3    1     6  0.299999         0.0   0.000000         587  2021/3
# 7      3    1     7  0.270000         0.0   0.000000         381  2021/3
# 8      3    1     8  0.399998         0.0   0.000000         381  2021/3
# 9      3    1     9  0.219997         0.0   0.050003         294  2021/3

# %% [markdown]
# #### **2) Checking the correlation between variables**

# %%
# 시각화를 위한 필요한 변수만 남기고, 나머지 변수는 제거하기

# 제거한 변수 #
# dt : 날짜
# year : 연도
# month : 월
# day : 일
# hour : 시간
# place : 시정 측정한 위치

# uws_10m : x축 풍속
# vws_10m : y축 풍속
# precipitation : 강수량
# relative_humidity_1p5m : 상대습도
# specific_humidity_1p5m : 절대습도
# grid_kWh : 그리드 소비(kWh)
# export_kWh : 수출 된 에너지(kWh)
# yield_kWh : 에너지 수율(kWh)

reg_data_vis = reg_data.drop(['dt', 'year', 'month', 'day', 'hour', 'place',
                              'uws_10m', 'vws_10m', 'precipitation', 'relative_humidity_1p5m', 'specific_humidity_1p5m',
                              'grid_kWh', 'export_kWh', 'yield_kWh'], axis=1)

# %%
# Heatmap Options
# annot=True : 실제 값 표시하기
# linewidths : 경계면 실선으로 구분하기
# cmap : 컬러 설정하기
# vmin, vmax : 컬러바 범위 설정하기
plt.figure(figsize=(10, 10))
sns.heatmap(data=reg_data_vis.corr(), annot=True, fmt='.2f', linewidths=.5, cmap='RdYlBu_r', vmin=-1, vmax=1)
plt.title("Variables Corrplot")
plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# #### **Case 3 : 에너지 수율(kWh)**
# - 참고 : Case 1(그리드 소비(kWh)), Case 2(수출 된 에너지(kWh))는 생략.

# %% [markdown]
# #### Package 1 : Scikit-learn

# %% [markdown]
# #### (0) year/month filtering

# %%
reg_data_f = reg_data[reg_data.ym == '2021/4']

# %% [markdown]
# #### (1) Training & Test Set Split from data other than NA

# %%
x = reg_data_f.dropna(axis=0)[['temperature', 'ghi', 'visibility']]
# x.visibility = np.log(x.visibility)
y = reg_data_f.dropna(axis=0)[['yield_kWh']]

x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, test_size=0.2)

# %%
# Matrix Scatter Plot
sns.set(rc={'figure.figsize':(15, 15)})
xydata = reg_data_f.dropna(axis=0)[['yield_kWh', 'temperature', 'ghi', 'visibility']]
sns.pairplot(xydata, diag_kind='hist')
plt.show()

# %% [markdown]
# #### (2) Modeling

# %%
# Initialization
lin_reg = linear_model.LinearRegression(fit_intercept=True)

# %%
# Fitting
lin_reg_model = lin_reg.fit(x_train, y_train)

# %%
# Predicting(Estimated values)
y_predict = lin_reg_model.predict(x_test)

# %%
# Visualization confirmation
sns.set(rc={'figure.figsize':(15, 7)})
plt.scatter(y_test, y_predict, alpha=0.5)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Multiple Linear Regression')
plt.show()

# %% [markdown]
# #### (3) Checking coefficients and constants

# %%
print(lin_reg_model.coef_)
# Out:
# [[-2.76328653e-02  3.42407097e-03  1.19533734e-05]]

# %% [markdown]
# #### (4) Accuracy Test

# %%
# R-Squared
print(lin_reg_model.score(x_train, y_train))
# Out:
# 0.8508595817501738

# %% [markdown]
# #### Package 2 : Statsmodels

# %% [markdown]
# #### (1) Checking fitting results
# - F-statistic : 도출된 회귀식이 회귀분석 모델 전체에 대해 통계적으로 의미가 있는지 파악
# - P-value : 각 변수가 종속변수에 미치는 영향이 유의한지 파악
# - Adjusted R-square : 회귀직선이 종속변수의 몇 %를 설명할 수 있는지 확인

# %%
x_train_const = sm.add_constant(x_train)
model = sm.OLS(y_train, x_train_const)
results = model.fit()

# %%
# 결과값 요약 확인
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              yield_kWh   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     1088.
# Date:                Wed, 03 Aug 2022   Prob (F-statistic):          7.84e-236
# Time:                        13:20:22   Log-Likelihood:                -168.45
# No. Observations:                 576   AIC:                             344.9
# Df Residuals:                     572   BIC:                             362.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.3251      0.070      4.651      0.000       0.188       0.462
# temperature    -0.0276      0.003     -8.431      0.000      -0.034      -0.021
# ghi             0.0034   8.06e-05     42.502      0.000       0.003       0.004
# visibility   1.195e-05   3.16e-05      0.379      0.705      -5e-05     7.4e-05
# ==============================================================================
# Omnibus:                       42.177   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              178.725
# Skew:                           0.072   Prob(JB):                     1.55e-39
# Kurtosis:                       5.725   Cond. No.                     9.69e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# VIF(분산 팽창 인수)
for i in range(1, len(model.exog_names)):
    vif = variance_inflation_factor(model.exog, i)
    print(f'Variable: {model.exog_names[i]}, VIF: {vif.round(2)}')
# Out:
# Variable: temperature, VIF: 2.44
# Variable: ghi, VIF: 2.45
# Variable: visibility, VIF: 1.01

# %% [markdown]
# #### (2) Checking residuals
# - 회귀모형에 대한 가정(정규성, 등분산성, 독립성)을 충족하는지에 대한 검정
# - 이상치가 개입하는지에 대한 검정을 하는 절차

# %% [markdown]
# ##### (2-1) Linearity of the model
# - 예측값(y_predict)과 잔차(residuals)의 비교
# - 모든 예측값에서 잔차가 비슷하게 있어야 함(가운데 점선).
# - 빨간 실선은 잔차의 추세를 나타냄.
# - 빨간 실선이 점선을 크게 벗어난다면 예측값에 따라 잔차가 크게 달라진다는 것임.

# %%
residuals = y_test - y_predict

sns.set(rc={'figure.figsize':(15, 7)})
sns.regplot(y_predict, residuals, lowess=True, line_kws={'color': 'red'})
plt.plot([y_predict.min(), y_predict.max()], [0, 0], '--', color='grey')
plt.title("Residuals Plot")
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()
# Out:
# C:\Users\mazy4\anaconda3\envs\Energy_Analysis\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### (2-2) Actual and Residuals Plot

# %%
residuals = y_test - y_predict

sns.set(rc={'figure.figsize':(15, 7)})
sns.regplot(y_test, residuals, lowess=True, line_kws={'color': 'red'})
plt.plot([y_test.min(), y_test.max()], [0, 0], '--', color='grey')
plt.title("Residuals Plot")
plt.xlabel("Actual")
plt.ylabel("Residuals")
plt.show()
# Out:
# C:\Users\mazy4\anaconda3\envs\Energy_Analysis\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### (2-3) Independent variables and Residuals Plot

# %% [markdown]
# ##### (2-3-1) GHI and Residuals

# %%
residuals = y_test - y_predict

sns.set(rc={'figure.figsize':(15, 7)})
sns.regplot(x_test.ghi, residuals, lowess=True, line_kws={'color': 'red'})
plt.plot([x_test.ghi.min(), x_test.ghi.max()], [0, 0], '--', color='grey')
plt.title("Residuals Plot")
plt.xlabel("GHI")
plt.ylabel("Residuals")
plt.show()
# Out:
# C:\Users\mazy4\anaconda3\envs\Energy_Analysis\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### (2-3-2) Visibility and Residuals Plot

# %%
residuals = y_test - y_predict

sns.set(rc={'figure.figsize':(15, 7)})
sns.regplot(x_test.visibility, residuals, lowess=True, line_kws={'color': 'red'})
plt.plot([x_test.visibility.min(), x_test.visibility.max()], [0, 0], '--', color='grey')
plt.title("Residuals Plot")
plt.xlabel("Visibility")
plt.ylabel("Residuals")
plt.show()
# Out:
# C:\Users\mazy4\anaconda3\envs\Energy_Analysis\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\mazy4\anaconda3\envs\Energy_Analysis\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in true_divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),

# %% [markdown]
# ##### (2-3-3) Temperature and Residuals Plot

# %%
residuals = y_test - y_predict

sns.set(rc={'figure.figsize':(15, 7)})
sns.regplot(x_test.temperature, residuals, lowess=True, line_kws={'color': 'red'})
plt.plot([x_test.temperature.min(), x_test.temperature.max()], [0, 0], '--', color='grey')
plt.title("Residuals Plot")
plt.xlabel("Temperature")
plt.ylabel("Residuals")
plt.show()
# Out:
# C:\Users\mazy4\anaconda3\envs\Energy_Analysis\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### (2-4) Normality of residuals
# - 잔차가 정규분포를 따른다는 가정
# - Shapiro Test를 통해 확인할 수 있음.

# %%
scipy.stats.shapiro(residuals)
# Out:
# ShapiroResult(statistic=0.9259388446807861, pvalue=8.204495998143102e-07)

# %% [markdown]
# ##### (2-5) Equivariance of residuals
# - 회귀모형을 통해 예측된 값이 크던 작던, 모든 값을에 대하여 잔차의 분산이 동일하다는 가정
# - 아래 그래프는 예측값(가로축)에 따라 잔차가 어떻게 달라지는지 보여줌.
# - 빨간색 실선이 수평선을 그리는 것이 이상적임.

# %%
sr = scipy.stats.zscore(residuals)
sns.regplot(y_predict, np.sqrt(np.abs(sr)), lowess=True, line_kws={'color': 'red'})
plt.title("Equivariance of residuals Plot")
plt.xlabel("Predicted")
plt.ylabel("Sqrt_Abs_Residuals_Zscore")
plt.show()
# Out:
# C:\Users\mazy4\anaconda3\envs\Energy_Analysis\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
